# %%
# Importacion de librerias
# from google.colab import drive    # Para usar archivos de drive
import nltk # Para NLP
import re     # Manejo de expresiones regulares
import numpy as np    # Para manejo de arreglos
from bs4 import BeautifulSoup # Para manejar HTML
import stanza # Para NLP
from sklearn.feature_extraction.text import CountVectorizer     # Para vectorizar el contexto
from sklearn.feature_extraction.text import TfidfTransformer    # Para vectorizar el contexto con IDF

# Descargamos recurso para incluir word_tokenizer
# nltk.download('punkt')
# nltk.download('punkt_tab')

# %%
# Manejo de Archivos

# Apertura de archivos
def openA(rutaArchivo):
  return open(rutaArchivo, 'r', encoding='utf-8')

# Escritura de archivos
def writeA(rutaArchivo, data):
  file = open(rutaArchivo,"w", encoding='utf-8')
  file.write(str(data))
  file.close()

# Lectura del archivo
def readA(archivo):
  contenido = archivo.read()
  return contenido

# %%
# Preprocesamiento

# Limpieza del archivo
def clean(plainText):
  # Expresion regular para eliminar los xml tags y saltos de linea
  regex_xml = r'<[^>]+>'

  # Quitando del texto los xml tags
  # texto = re.sub(regex_xml, '', plainText)
  soup = BeautifulSoup(plainText, "lxml")
  texto = soup.get_text()

  # Pasando a lowercase
  texto = texto.lower()

  return texto


# Tokenizacion
def tokenizacion(texto):
  # tokens = nltk.word_tokenize(texto)
  tokens = nltk.sent_tokenize(texto)
  nlp = stanza.Pipeline(lang="es", processors='tokenize, lemma, mwt, pos') if True else None
  doc = nlp(texto)
  return tokens, doc

# Limpieza de tokens, Eliminar todos los tokens que no son palabras (Todo lo que no sea letra del alfabeto)
def cleanTokens(tokens, doc):
  # tokens = [token for token in tokens if token.isalpha()]
  word_tokens = set()
  word_frequencies = {}
  sentences_processed = []
  for sentence in doc.sentences:
    processed_sentence = []
    tokens = [(word.lemma if True else word.text) for word in sentence.words]
    #Filtrar tokens.
    for token in tokens:
        token = re.sub(r"-", "", token)
        if not token.isalpha():
            continue
        #Ignorar numeros romanos
        if re.match(r"^M{0,3}(CM|CD|D?C{0,3})?(XC|XL|L?X{0,3})?(IX|IV|V?I{0,3})?$", token):
            continue
        if re.match(r"^m{0,3}(cm|cd|d?c{0,3})?(xc|xl|l?X{0,3})?(ix|iv|v?i{0,3})?$", token):
            continue
        #Pasar a minúsculas.
        token = token.lower()
        token = re.sub(r"[\W\d_\s]", "", token)
        #Ignorar tokens vacios
        if re.match(r"^\s$", token) or len(token) < 2:
            continue 
        # #Ignorar stopwords            
        # if remove_stopwords and (token in stopwords):
        #     continue

        processed_sentence.append(token)
        word_tokens.add(token)
        word_frequencies[token] = word_frequencies.get(token, 0) + 1
        if processed_sentence not in sentences_processed:
          sentences_processed.append(processed_sentence)
  return sorted(word_tokens), sentences_processed, word_frequencies

# Eliminacion de stopwords
def deleteStopwords(tokens):
  return tokens

# Lematización del texto
def lemaText(tokens):
  return tokens

# Preprocesamiento del texto
def preproText(plainText):
  text = clean(plainText)
  tokens, doc = tokenizacion(text)
  print("Tokens sin limpiar: ", tokens)
  tokens = cleanTokens(tokens, doc)
  print("Tokens limpios: ", tokens)
  return tokens

# Parseador de texto a Text
def parseText(tokens):
  # NOTA: Para obtener la frecuencia de distribución primero debemos parsear el texto con Text
  text = nltk.Text(tokens)
  print("Texto parseado: ", text)
  
  return text

# Generar el vocabulario
def getVocabulary(tokens, text):
  fdist = nltk.FreqDist(text)          # Da el total de palabras que se han contado
  vocabulary = fdist.keys()            # Da una lista de todos los tipos distintos de palabras en el texto
  vocabulary = sorted(vocabulary)      # Ordanamiento alfabeticamente

  return vocabulary

# %%
# Codificacion en espacio vectorial con bolsa de palabras

"""
Función que obtiene los contextos de una palabra
@param texto: Son los tokens parseados a Texto
@param word: Es la palabra a buscar el contexto (En este caso cada una del vocabulario)
@param w: Es la ventana con la que se trabajara (En este caso es de 8 (4 para izquierda - 4 para derecha))
"""
def getContextCollection(texto, word, w):
  wLeft = wRight = w//2
  contexto_left = []
  contexto_right = []
  contextoW = {}
  aux = []

  print("Tipo de texto: ", type(texto))
  # Obteniendo la concordancia (se imprime)
  # texto.concordance(word)

  # Contamos la candidad de concordancia
  cantidadConcordancias = texto.count(word)

  for concordancia in texto.concordance_list(word):  # Ejemplo de documentacion de concordance: https://www.nltk.org/howto/concordance.html#concordance-list
        # Creacion de AUX para conocer la palabra anterior
        aux.append(word)
        # La línea de la concordancia contiene la palabra objetivo y su contexto
        linea = concordancia.line
        tokens_linea = linea.split()

        # Buscamos la posición de la palabra brindada en la línea
        indice = tokens_linea.index(word)

        # Extraemos los 4 tokens a la izquierda y derecha
        izquierda = tokens_linea[max(0, indice-wLeft):indice]
        derecha = tokens_linea[(indice+1):max(0, (indice+wRight+1))]

        # Guardamos los tokens en un arreglo
        if len(aux) == 1:
          contexto_left = izquierda
          contexto_right = derecha

        elif aux[-2] == word:
          contexto_left = contexto_left + izquierda
          contexto_right = contexto_right + derecha

        # Unimos los contextos
        contextoW = contexto_left + contexto_right
  return contexto_left, contexto_right, contextoW

# Creacion de lista de contextos ([contexto_w1, contexto_w2,...,contexto_wn])
def getBagWords(text, vocabulary):
  contextos = {}
  for key, sentence in text:
    contextos[key] = []
    for word in vocabulary:
        _, _, contexto = getContextCollection(sentence, word, 8)
        contextos.append(contexto)
  return contextos

# Creacion de vetor con valores de Document Frecuency
def getDocumentF(bagWords):
  idf = []
  for vectorTerm in bagWords:
    count = 0
    for context in vectorTerm:
      if context != 0:
        count = count + 1
    idf.append(count)

  return idf


###############################################################################################################################################################################
# Vectorizacion
def vectorizacion(bagWords, lenVocabulary, typeV):
  # Convertimos en una sola cadena (separada por espacios) cada uno de los contextos (documentos)
  documentos = [' '.join(doc) for doc in bagWords]

  # Inicializamos CountVectorizer
  vectorizer = CountVectorizer() # https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

  # Vectorizamos los documentos
  vectores = vectorizer.fit_transform(documentos)

  matrizF = vectores.toarray() # Convierte vectores a una matriz densa
  # Tranformacion de la matriz segun el tipo de vectorizacion
  if typeV == 1: # Count
    matrizF = matrizF
  elif typeV == 2: # Frecuencia Relativa
    matrizF = matrizF / np.sum(matrizF, axis=1).reshape(-1, 1)
  elif typeV == 3: # TF con log (Transformacion sublineal)
    matrizF = np.log(1 + matrizF)
  elif typeV == 4: # IDF
    # k = np.array(getDocumentF(bagWords))
    # print(k)
    # for i in range(lenVocabulary):
    #   matrizF[i] = float(np.log(lenVocabulary + 1 / k[i]))
    # print(matrizF)
    idf = TfidfTransformer(use_idf=True, smooth_idf=False, sublinear_tf=False)
    matrizF_idf = idf.fit_transform(matrizF)
    matrizF = matrizF_idf.toarray()

  # Obteniendo los nombres de cada vector
  namesVectors = vectorizer.get_feature_names_out()

  # Creando diccionario de palabra con su vector
  dicVectorWord = {}
  for i in range(lenVocabulary):
    dicVectorWord[namesVectors[i]] = matrizF[i].tolist()

  return dicVectorWord

# %%
# Mediciones de similitud
"""
Funcion para obtener el coseno entre 2 vectores
"""
def getCos(x , y): # xy / |x||y|
  pDot = np.dot(x,y)
  normaX = np.linalg.norm(x)
  normaY = np.linalg.norm(y)
  pNorma = np.dot(normaX, normaY)
  cos = pDot / pNorma

  return round(cos, 3)

# %%
# Creacion de diccionario de similitudes
def getSimilitud(word, dicVecWord):
  similitud = {}
  for doc in dicVecWord:
    cosenoT = getCos(dicVecWord[word], dicVecWord[doc])
    similitud[doc] = float(cosenoT)

  similitud = dict(sorted(similitud.items(), key=lambda item: item[1], reverse=True))

  return similitud

# %%
# Main
# rutaArchivo = "/content/drive/MyDrive/PLN/Textos/e990505_mod.htm"
rutaArchivo = "./Textos/e990505_mod.htm"

archivo = openA(rutaArchivo)
plainText = readA(archivo)
tokens, sentences, freq = preproText(plainText)
text = parseText(sentences)
tokensParsed = parseText(tokens)
vocabulary = getVocabulary(tokens, tokensParsed)
# Out:
# 2025-07-10 17:55:24 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 433kB [00:00, 10.1MB/s]
# 2025-07-10 17:55:24 INFO: Downloaded file to C:\Users\reini\stanza_resources\resources.json
# 2025-07-10 17:55:24 INFO: Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# 2025-07-10 17:55:24 INFO: Using device: cpu
# 2025-07-10 17:55:24 INFO: Loading: tokenize
# 2025-07-10 17:55:27 INFO: Loading: mwt
# 2025-07-10 17:55:27 INFO: Loading: pos
# 2025-07-10 17:55:29 INFO: Loading: lemma
# 2025-07-10 17:55:31 INFO: Done loading processors!
# Tokens sin limpiar:  ['\n\n\ne990505_mod.htm\n\n\n\nhttp://www.excelsior.com.mx/9905/990505/art01.html\n\n\nexcelsior: editorial\n\n\nmiércoles 05 de mayo de 1999\n\nepigrama\n\njorge mansilla torres\n\nla diputada raquel sevilla, dueña de una violencia verbal envidiable, camina con un collarín ortopédico.', 'y no faltó el periodista\nque con lenguaje letal,\ndijo que la asambleísta\n¡mejor se ponga un bozal..!', 'editorial -\nnota siguiente\n\nhttp://www.excelsior.com.mx/9905/990505/art02.html\n\n\nexcelsior: editorial\n\n\nmiércoles 05 de mayo de 1999\n\nliquidar a milosevic\n\ntranquilizar la mala conciencia\n\njorge ruiz dueñas\n\nlos voceros de la casa blanca y de la otan se han referido, a la fórmula de los bombardeos sobre las ciudades yugoslavas, como el castigo necesario para liquidar a slobodan milosevic.', 'incluso, se dice, el conflicto actual es el precio de no haber actuado antes en el desmembramiento de la yugoslavia de tito.', 'el sufrimiento de las familias desplazadas, sin duda, nos muestra de nuevo esa cara de la moneda donde destaca el perfil de caín.', 'viejos, niños, mujeres, hombres de familia, son desalojados de sus tierras y casas, por un nacionalismo excluyente.', 'se
# Texto parseado:  <Text: ['excelsior', 'editorial'] ['miércoles', 'de', 'mayo', 'de'] ['epigrama'] ['jorge', 'mansilla', 'torre'] ['el', 'diputada', 'raquel', 'sevilla', 'dueña', 'de', 'uno', 'violencia', 'verbal', 'envidiable', 'caminar', 'con', 'uno', 'collarín', 'ortopédico'] ['no', 'faltar', 'el', 'periodista', 'que', 'con', 'lenguaje', 'letal', 'decir', 'que', 'el', 'asambleísta', 'mejor', 'él', 'poner', 'uno', 'bozal'] ['editorial', 'nota', 'siguiente'] ['excelsior', 'editorial']...>
# Texto parseado:  <Text: aas abajo abanderado abandonado abandonar abandono abastecer abatir...>

# %%
# type(text)
type(tokensParsed)
# type(vocabulary)
# Out:
# nltk.text.Text

# %%
bagOfWords = getBagWords(text, vocabulary)
print("Bag of Words: ", bagOfWords)
# Out:
# Tipo de texto:  <class 'str'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 bagOfWords = getBagWords(text, vocabulary)
#       2 print("Bag of Words: ", bagOfWords)
#
# Cell In[89], line 56, in getBagWords(text, vocabulary)
#      54   contextos[key] = []
#      55   for word in vocabulary:
# ---> 56       _, _, contexto = getContextCollection(sentence, word, 8)
#      57       contextos.append(contexto)
#      58 return contextos
#
# Cell In[89], line 23, in getContextCollection(texto, word, w)
#      17 # Obteniendo la concordancia (se imprime)
#      18 # texto.concordance(word)
#      19
#      20 # Contamos la candidad de concordancia
#      21 cantidadConcordancias = texto.count(word)
# ---> 23 for concordancia in texto.concordance_list(word):  # Ejemplo de documentacion de concordance: https://www.nltk.org/howto/concordance.html#concordance-list
#      24       # Creacion de AUX para conocer la palabra anterior
#      25       aux.append(word)
#      26       # La línea de la concordancia contiene la palabra objetivo y su contexto
#
# AttributeError: 'str' object has no attribute 'concordance_list'

# %%
print("Vocabulario: ", vocabulary)
print("Tokens: ", tokens)
print("Sentences: ", sentences)
print("Frecuencias: ", freq)
# Out:
# Vocabulario:  ['aas', 'abajo', 'abanderado', 'abandonado', 'abandonar', 'abandono', 'abastecer', 'abatir', 'abdicar', 'aberrante', 'abiertamente', 'abierto', 'abigeato', 'abm', 'abogado', 'abogar', 'abolir', 'abonar', 'abono', 'abordar', 'abrazar', 'abrego', 'abril', 'abrir', 'absolutismo', 'absoluto', 'abstener', 'abundancia', 'abundar', 'acabar', 'academia', 'académico', 'acahualtepec', 'acalorado', 'acapulco', 'acaso', 'acatar', 'acceder', 'acceso', 'accidentar', 'accidente', 'accionario', 'acción', 'acelerar', 'aceptable', 'aceptación', 'aceptar', 'acerca', 'acercamiento', 'acercar', 'acertado', 'aclarar', 'acometer', 'acompañado', 'acompañar', 'acontecer', 'acontecimiento', 'acordado', 'acordar', 'acosta', 'acotado', 'acotar', 'acrecentar', 'acreditar', 'acreedor', 'acta', 'acteal', 'actitud', 'activar', 'actividad', 'activo', 'acto', 'actor', 'actuación', 'actual', 'actualidad', 'actualización
': 13, 'obligación': 3, 'moral': 15, 'intervenir': 13, 'ante': 40, 'masacre': 1, 'aunque': 35, 'expediente': 3, 'alguno': 70, 'poderoso': 8, 'alianza': 20, 'consistente': 2, 'mismo': 60, 'javier': 8, 'solano': 2, 'tampoco': 15, 'escapa': 1, 'contradicción': 2, 'remediar': 1, 'este': 294, 'mal': 5, 'organización': 19, 'proponer': 8, 'diestro': 1, 'siniestro': 1, 'lograr': 21, 'otro': 158, 'gloria': 3, 'sólo': 54, 'recuento': 2, 'halcón': 1, 'paloma': 1, 'televisión': 3, 'hacer': 139, 'drama': 1, 'talking': 1, 'show': 1, 'industria': 22, 'reactivar': 2, 'prestigio': 2, 'estar': 200, 'alza': 15, 'voluta': 1, 'humo': 1, 'visto': 2, 'distancia': 7, 'quien': 68, 'también': 97, 'violar': 6, 'derecho': 35, 'humano': 30, 'tratar': 35, 'emigrante': 1, 'latinoamericano': 9, 'comentario': 8, 'estilo': 4, 'calificar': 5, 'pacifismo': 1, 'chato': 1, 'seguramente': 3, 'ya': 88, 'preparar': 5, 'plan': 18, 'financiero': 72, 'reconstrucción': 4, 'zona': 13, 'próximo': 20, 'cautivar': 1, 'deuda': 9, 'impagable': 1, 'decenio': 2, 'giro': 3, 'panamá': 4, 'populismo': 1, 'derechista': 1, 'lisandro': 1, 'otero': 1, 'elección': 35, 'mireya': 2, 'moscoso': 4, 'presidenta': 1, 'marcar': 2, 'importante': 33, 'política': 58, 'centroamericano': 1, 'implicar': 4, 'recuperación': 7, 'poder': 171, 'populista': 1, 'derecha': 1, 'continuar': 21, 'tradición': 2, 'conservador': 5, 'fallecido': 1, 'arnulfo': 2, 'ario': 1, 'elegir' ...

# %%
writeA("./Salidas/text.txt", text.concordance_list)

# %%
dicVectorWord = vectorizacion(bagOfWords, len(vocabulary), 1)
similitud = getSimilitud("organización", dicVectorWord)
writeA("/content/drive/MyDrive/PLN/Practicas/Ejercicio1/Salidas/similitudRaw.json", similitud)
print(similitud)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 dicVectorWord = vectorizacion(bagOfWords, len(vocabulary), 1)
#       2 similitud = getSimilitud("organización", dicVectorWord)
#       3 writeA("/content/drive/MyDrive/PLN/Practicas/Ejercicio1/Salidas/similitudRaw.json", similitud)
#
# Cell In[29], line 80, in vectorizacion(bagWords, lenVocabulary, typeV)
#      77 vectorizer = CountVectorizer() # https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
#      79 # Vectorizamos los documentos
# ---> 80 vectores = vectorizer.fit_transform(documentos)
#      82 matrizF = vectores.toarray() # Convierte vectores a una matriz densa
#      83 # Tranformacion de la matriz segun el tipo de vectorizacion
#
# File c:\Users\reini\Escritorio\SegundoSemestre\TratamientoDeLenguajeNatural\Practicas\env\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\reini\Escritorio\SegundoSemestre\TratamientoDeLenguajeNatural\Practicas\env\Lib\site-packages\sklearn\feature_extraction\text.py:1376, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1368             warnings.warn(
#    1369                 "Upper case characters found in"
#    1370                 " vocabulary while 'lowercase'"
#    1371                 " is True. These entries will not"
#    1372                 " be matched with any documents"
#    1373             )
#    1374             break
# -> 1376 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1378 if self.binary:
#    1379     X.data.fill(1)
#
# File c:\Users\reini\Escritorio\SegundoSemestre\TratamientoDeLenguajeNatural\Practicas\env\Lib\site-packages\sklearn\feature_extraction\text.py:1282, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1280     vocabulary = dict(vocabulary)
#    1281     if not vocabulary:
# -> 1282         raise ValueError(
#    1283             "empty vocabulary; perhaps the documents only contain stop words"
#    1284         )
#    1286 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1287     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
dicVectorWord = vectorizacion(bagOfWords, len(vocabulary), 2)
similitud = getSimilitud("organización", dicVectorWord)
writeA("/content/drive/MyDrive/PLN/Practicas/Ejercicio1/Salidas/similitudFrecuencia.json", similitud)
print(similitud)
# Out:
# {'organización': 1.0, 'sala': 0.717, 'raron': 0.7, 'licitación': 0.699, 'recupere': 0.699, 'eso': 0.688, 'función': 0.685, 'desde': 0.68, 'ferrando': 0.676, 'crédito': 0.675, 'maestra': 0.668, 'equidad': 0.666, 'fugas': 0.663, 'oponerse': 0.66, 'afamada': 0.654, 'sean': 0.651, 'méritos': 0.649, 'concibió': 0.648, 'gasolinas': 0.643, 'apoyar': 0.641, 'emergente': 0.637, 'croc': 0.636, 'préstamo': 0.635, 'heridos': 0.632, 'medicina': 0.632, 'batres': 0.631, 'exactamente': 0.631, 'nacionalistas': 0.631, 'nivel': 0.63, 'cristiana': 0.629, 'efectuará': 0.629, 'contribuyó': 0.627, 'supuesto': 0.627, 'alcista': 0.625, 'ridades': 0.624, 'anota': 0.623, 'autorizaban': 0.623, 'argumentos': 0.621, 'cese': 0.62, 'encuesta': 0.62, 'epresidenta': 0.62, 'halagos': 0.62, 'emitidos': 0.619, 'obligó': 0.619, 'gabriel': 0.616, 'expresarle': 0.615, 'fraude': 0.615, 'subida': 0.615, 'periodismo': 0.613, 'región': 0.613, 'acercan': 0.612, 'diesel': 0.612, 'latinoamericanos': 0.609, 'moctezuma': 0.609, 'sólidas': 0.609, 'dizque': 0.608, 'analizar': 0.607, 'exportadora': 0.607, 'fotos': 0.607, 'garza': 0.607, 'mantenerme': 0.607, 'mundo': 0.607, 'sámano': 0.605, 'aunque': 0.604, 'fuimos': 0.604, 'armada': 0.603, 'fredrich': 0.602, 'mitad': 0.602, 'reparto': 0.602, 'estudiosos': 0.601, 'napoleón': 0.601, 'público': 0.601, 'revisaron': 0.601, 'stevens': 0.601, 'manifestar': 0.6, 'instigadores': 0.598, 'salvar': 0.598, 'bandido': 0.597, 'pib': 0.597, 'actitudes': 0.596, 'natividad': 0.596, 'sodi': 0.596, 'onetarias': 0.595, 'pgr': 0.595, 'enlatada': 0.594, 'salí': 0.594, 'informados': 0.593, 'interpreta': 0.593, 'fuesen': 0.592, 'legítimos': 0.592, 'agroindustria': 0.591, 'reconstrucción': 0.591, 'sólidos': 0.591, 'ordenada': 0.59, 'compromisos': 0.588, 'interior': 0.588, 'rostro': 0.588, 'raro': 0.587, 'afinarán': 0.586, 'albert': 0.586, 'cerraron': 0.586, 'expresiones': 0.586, 'logros': 0.586, 'escalada': 0.585, 'instituciones': 0.584, 'manero': 0.584, 'aspiraciones': 0.583, 'dirección': 0.583, 'interparlament': 0.583, '